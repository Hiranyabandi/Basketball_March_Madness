# %% [markdown]
# <a href="https://colab.research.google.com/github/Hiranyabandi/Basketball_March_Madness/blob/main/app_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Streamlit_Dashboard_Basketball**

# %%
import streamlit as st
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from math import pi

# Set up the page
st.set_page_config(page_title="March Madness 2025 Dashboard", layout="wide")
st.title("March Madness 2025 - Basketball Analytics")

# Load data files from the Data folder
df_teams = pd.read_csv("Data/filtered_2025_teams.csv", low_memory=False)
team_summary = pd.read_csv("Data/team_summary_2025.csv")
illinois_kentucky_df = pd.read_csv("Data/kentucky_vs_illinois_comparison.csv")
df_tagged = pd.read_csv("Data/off_def_split.csv")
df_clusters = pd.read_csv("Data/team_clusters.csv")
df_final4 = pd.read_csv("Data/final_four_vs_illinois.csv")

# Sidebar filters
st.sidebar.title("Filter Teams")
selected_team = st.sidebar.selectbox("Select a Team", df_teams["Full Team Name"].unique())

# Tab structure
tabs = st.tabs(["Team Overview", "Strategy Breakdown", "Illinois vs Kentucky", "Team Clusters", "Final Four Analysis"])

# --- Tab 1: Team Overview ---
with tabs[0]:
    st.header(f" {selected_team} - Overview Stats")
    team_data = df_teams[df_teams["Full Team Name"] == selected_team]
    st.dataframe(team_data.describe().T)

    st.subheader(" Plot: Offensive vs Defensive Efficiency")
    fig = px.scatter(df_teams, x="AdjOE", y="AdjDE", color="Full Team Name",
                     title="Offensive vs Defensive Efficiency", hover_name="Full Team Name")
    st.plotly_chart(fig, use_container_width=True)

# --- Tab 2: Strategy Breakdown ---
with tabs[1]:
    st.header(" Team Strategy Breakdown")
    category = st.selectbox("Select Feature Category", df_tagged["Category"].unique())
    filtered = df_tagged[df_tagged["Category"] == category]
    fig = px.box(filtered, x="Metric", y="Value", color="Metric",
                 title=f"Distribution of {category} Metrics")
    st.plotly_chart(fig, use_container_width=True)

# --- Tab 3: Illinois vs Kentucky ---
with tabs[2]:
    st.header(" Illinois vs Kentucky Comparison")
    fig = px.bar(illinois_kentucky_df, x="Metric", y=["Illinois", "Kentucky"],
                 barmode="group", title="Head-to-Head Metrics")
    st.plotly_chart(fig, use_container_width=True)

# --- Tab 4: Team Clusters ---
with tabs[3]:
    st.header(" Team Clustering View")
    fig = px.scatter(df_clusters, x="PC1", y="PC2", color="Cluster", text="Full Team Name",
                     title="Team Style Clusters")
    st.plotly_chart(fig, use_container_width=True)

# --- Tab 5: Final Four Comparison ---
with tabs[4]:
    st.header(" Illinois vs Final Four Teams")

    teams = df_final4["Team Compared to Illinois"].unique()
    selected = st.selectbox("Select Final Four Team", teams)

    filtered = df_final4[df_final4["Team Compared to Illinois"] == selected]

    fig = px.bar(filtered, x="Metric",
                 y=["Illinois Value", "Team Value"],
                 barmode="group",
                 title=f"Illinois vs {selected} - Metric Comparison")
    st.plotly_chart(fig, use_container_width=True)

    st.subheader(" Metric Differences (Negative = Illinois Lagging)")
    fig_diff = px.bar(filtered, x="Metric", y="Difference",
                      color="Difference",
                      color_continuous_scale='RdBu',
                      title=f"Statistical Gap: Illinois vs {selected}")
    st.plotly_chart(fig_diff, use_container_width=True)
# Out:
# 2025-07-19 19:29:32.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:32.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-19 19:29:33.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
